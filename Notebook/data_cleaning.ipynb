# %% [markdown]
# # 1. Load & Inspect Dataset

# %%
# Import Libraries
import numpy as np
import pandas as pd
from shapely import wkt

import warnings
warnings.filterwarnings('ignore')

# %%
# load the dataset
df= pd.read_csv(r"D:\#Great Learning\Capstone Project\Datasets\Traffic_Crash.csv")

# %%
df.head()
df.info()
df.describe(include='all')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300000 entries, 0 to 299999
# Data columns (total 48 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   CRASH_RECORD_ID                300000 non-null  object
#  1   CRASH_DATE_EST_I               21757 non-null   object
#  2   CRASH_DATE                     300000 non-null  object
#  3   POSTED_SPEED_LIMIT             300000 non-null  int64
#  4   TRAFFIC_CONTROL_DEVICE         300000 non-null  object
#  5   DEVICE_CONDITION               300000 non-null  object
#  6   WEATHER_CONDITION              300000 non-null  object
#  7   LIGHTING_CONDITION             300000 non-null  object
#  8   FIRST_CRASH_TYPE               300000 non-null  object
#  9   TRAFFICWAY_TYPE                300000 non-null  object
#  10  LANE_CNT                       59529 non-null   float64
#  11  ALIGNMENT                      300000 non-null  object
#  12  ROADWAY_SURFACE_COND           300000 non-null  object
#  13  ROAD_DEFECT                    300000 non-null  object
#  14  REPORT_TYPE                    290113 non-null  object
#  15  CRASH_TYPE                     300000 non-null  object
#  16  INTERSECTION_RELATED_I         68983 non-null   object
#  17  NOT_RIGHT_OF_WAY_I             13393 non-null   object
#  18  HIT_AND_RUN_I                  94538 non-null   object
#  19  DAMAGE                         300000 non-null  object
#  20  DATE_POLICE_NOTIFIED           300000 non-null  object
#  21  PRIM_CONTRIBUTORY_CAUSE        300000 non-null  object
#  22  SEC_CONTRIBUTORY_CAUSE         300000 non-null  object
#  23  STREET_NO                      300000 non-null  int64
#  24  STREET_DIRECTION               300000 non-null  object
#  25  STREET_NAME                    299999 non-null  object
#  26  BEAT_OF_OCCURRENCE             299999 non-null  float64
#  27  PHOTOS_TAKEN_I                 4289 non-null    object
#  28  STATEMENTS_TAKEN_I             7041 non-null    object
#  29  DOORING_I                      980 non-null     object
#  30  WORK_ZONE_I                    1646 non-null    object
#  31  WORK_ZONE_TYPE                 1249 non-null    object
#  32  WORKERS_PRESENT_I              430 non-null     object
#  33  NUM_UNITS                      300000 non-null  int64
#  34  MOST_SEVERE_INJURY             299351 non-null  object
#  35  INJURIES_TOTAL                 299355 non-null  float64
#  36  INJURIES_FATAL                 299355 non-null  float64
#  37  INJURIES_INCAPACITATING        299355 non-null  float64
#  38  INJURIES_NON_INCAPACITATING    299355 non-null  float64
#  39  INJURIES_REPORTED_NOT_EVIDENT  299355 non-null  float64
#  40  INJURIES_NO_INDICATION         299355 non-null  float64
#  41  INJURIES_UNKNOWN               299355 non-null  float64
#  42  CRASH_HOUR                     300000 non-null  int64
#  43  CRASH_DAY_OF_WEEK              300000 non-null  int64
#  44  CRASH_MONTH                    300000 non-null  int64
#  45  LATITUDE                       297699 non-null  float64
#  46  LONGITUDE                      297699 non-null  float64
#  47  LOCATION                       297699 non-null  object
# dtypes: float64(11), int64(6), object(31)
# memory usage: 109.9+ MB
#                                           CRASH_RECORD_ID CRASH_DATE_EST_I  \
# count                                              300000            21757
# unique                                             300000                2
# top     ee0b70ab08d3cbd410c1f3ecb3c3516f8038fe8047a0d6...                Y
# freq                                                    1            18969
# mean                                                  NaN              NaN
# std                                                   NaN              NaN
# min                                                   NaN              NaN
# 25%                                                   NaN              NaN
# 50%                                                   NaN              NaN
# 75%                                                   NaN              NaN
# max                                                   NaN              NaN
#
#               CRASH_DATE  POSTED_SPEED_LIMIT TRAFFIC_CONTROL_DEVICE  \
# count             300000        300000.00000                 300000
# unique            254547                 NaN                     19
# top     02-06-2025 08:00                 NaN            NO CONTROLS
# freq                  10                 NaN                 169185
# mean                 NaN            28.42684                    NaN
# std                  NaN             6.05171                    NaN
# min                  NaN             0.00000                    NaN
# 25%                  NaN            30.00000                    NaN
# 50%                  NaN            30.00000                    NaN
# 75%                  NaN            30.00000                    NaN
# max                  NaN            99.00000                    NaN
#
#        DEVICE_CONDITION WEATHER_CONDITION LIGHTING_CONDITION  \
# count            300000            300000             300000
# unique                8                12                  6
# top         NO CONTROLS             CLEAR           DAYLIGHT
# freq             171278            236215             192890
# mean                NaN               NaN                NaN
# std                 NaN               NaN                NaN
# min                 NaN               NaN                NaN
# 25%                 NaN               NaN                NaN
# 50%                 NaN               NaN                NaN
# 75%                 NaN               NaN                NaN
# max                 NaN               NaN                NaN
#
#             FIRST_CRASH_TYPE TRAFFICWAY_TYPE  ...  \
# count                 300000          300000  ...
# unique                    18              20  ...
# top     PARKED MOTOR VEHICLE     NOT DIVIDED  ...
# freq                   69363          128524  ...
# mean                     NaN             NaN  ...
# std                      NaN             NaN  ...
# min                      NaN             NaN  ...
# 25%                      NaN             NaN  ...
# 50%                      NaN             NaN  ...
# 75%                      NaN             NaN  ...
# max                      NaN             NaN  ...
#
#         INJURIES_NON_INCAPACITATING INJURIES_REPORTED_NOT_EVIDENT  \
# count                 299355.000000                 299355.000000
# unique                          NaN                           NaN
# top                             NaN                           NaN
# freq                            NaN                           NaN
# mean                       0.110100                      0.067789
# std                        0.425147                      0.336534
# min                        0.000000                      0.000000
# 25%                        0.000000                      0.000000
# 50%                        0.000000                      0.000000
# 75%                        0.000000                      0.000000
# max                       18.000000                     11.000000
#
#        INJURIES_NO_INDICATION INJURIES_UNKNOWN     CRASH_HOUR  \
# count           299355.000000         299355.0  300000.000000
# unique                    NaN              NaN            NaN
# top                       NaN              NaN            NaN
# freq                      NaN              NaN            NaN
# mean                 1.999155              0.0      13.180733
# std                  1.169587              0.0       5.574193
# min                  0.000000              0.0       0.000000
# 25%                  1.000000              0.0       9.000000
# 50%                  2.000000              0.0      14.000000
# 75%                  2.000000              0.0      17.000000
# max                 61.000000              0.0      23.000000
#
#        CRASH_DAY_OF_WEEK    CRASH_MONTH       LATITUDE      LONGITUDE  \
# count      300000.000000  300000.000000  297699.000000  297699.000000
# unique               NaN            NaN            NaN            NaN
# top                  NaN            NaN            NaN            NaN
# freq                 NaN            NaN            NaN            NaN
# mean            4.117217       6.686750      41.856194     -87.675518
# std             1.981695       3.363232       0.279365       0.559775
# min             1.000000       1.000000       0.000000     -87.934763
# 25%             2.000000       4.000000      41.783866     -87.721945
# 50%             4.000000       7.000000      41.875131     -87.674501
# 75%             6.000000      10.000000      41.924678     -87.633779
# max             7.000000      12.000000      42.022780       0.000000
#
#                                         LOCATION
# count                                     297699
# unique                                    152791
# top     POINT (-87.905309125103 41.976201139024)
# freq                                         447
# mean                                         NaN
# std                                          NaN
# min                                          NaN
# 25%                                          NaN
# 50%                                          NaN
# 75%                                          NaN
# max                                          NaN
#
# [11 rows x 48 columns]

# %% [markdown]
# # Standardizing Column Names

# %%
# # Convert column names to lowercase + snake_case
# df.columns= (
#     df.columns.str.strip()
#               .str.lower()
#               .str.replace(' ','_')
#               .str.replace('(','')
#               .str.replace(')','')
#               .str.replace('-','_')
# )
# df.head()

# %% [markdown]
# # Handle Date & Time Columns

# %%
# dataset has CRASH_DATE and DATE_POLICE_NOTIFIED in string formats:
# convert them into date time

df['CRASH_DATE'] = pd.to_datetime(df['CRASH_DATE'], errors='coerce')
df['DATE_POLICE_NOTIFIED'] = pd.to_datetime(df['DATE_POLICE_NOTIFIED'], errors='coerce')

# %%
#Create useful new features.
df['CRASH_YEAR'] = df['CRASH_DATE'].dt.year
df['CRASH_MONTH'] = df['CRASH_DATE'].dt.month
df['CRASH_HOUR'] = df['CRASH_DATE'].dt.hour
df['CRASH_DAY'] = df['CRASH_DATE'].dt.day_name()

# %% [markdown]
# # Clean Location Columns

# %%
# LATITUDE, LONGITUDE, LOCATION must be separated. If LOCATION contains (lat lon), extract clean numeric values:
df['LATITUDE'] = pd.to_numeric(df['LATITUDE'], errors='coerce')
df['LONGITUDE'] = pd.to_numeric(df['LONGITUDE'], errors='coerce')

# %%
# Drop LOCATION column (redundant):
df.drop(columns=['LOCATION'], inplace=True)

# %% [markdown]
# # Standardize Boolean Columns

# %%
# Columns such as INTERSECTION_RELATED_I, HIT_AND_RUN_I, WORK_ZONE_I, PHOTOS_TAKEN_I
# contain values like Y / N or blank.

# Convert to binary format:
columns = ['INTERSECTION_RELATED_I','NOT_RIGHT_OF_WAY_I','HIT_AND_RUN_I','PHOTOS_TAKEN_I',
           'STATEMENTS_TAKEN_I','DOORING_I','WORK_ZONE_I','WORKERS_PRESENT_I']

for col in columns:
    df[col] = df[col].map({'Y':1,'N':0})
    df[col] = df[col].fillna(0)

# %% [markdown]
# # Fix Injury Columns

# %%
#Dataset has many injury-related columns like:
# INJURIES_TOTAL, INJURIES_FATAL, INJURIES_REPORTED_NOT_EVIDENT, ...

# Convert them into integer type & fill NAs:

inj_cols = [col for col in df.columns if 'INJURIES' in col]

for col in inj_cols:
    df[col] = pd.to_numeric(df[col], errors='coerce').fillna(0).astype(int)

# %% [markdown]
# # Handle Categorical Columns

# %%
# We have many categorical fields (WEATHER_CONDITION, FIRST_CRASH_TYPE, etc.)

# Encode using LabelEncoder or One-Hot Encoding
# cat_cols = df.select_dtypes(include='object').columns
# df = pd.get_dummies(df, columns=cat_cols, drop_first=True)

from sklearn.preprocessing import LabelEncoder

cat_cols = df.select_dtypes(include='object').columns
le = LabelEncoder()

for col in cat_cols:
    df[col] = le.fit_transform(df[col].astype(str))

# %% [markdown]
# # Handle Missing Values

# %%
# For numeric columns — use median
# For categorical columns — use mode

num = df.select_dtypes(include='number').columns
cat = df.select_dtypes(include='object').columns

df[num] = df[num].fillna(df[num].median())
df[cat] = df[cat].fillna(df[cat].mode().iloc[0])

# %%
# Remove Irrelevant Columns
# Drop IDs, exact addresses if not needed for prediction
df.drop(columns=['CRASH_RECORD_ID'], inplace=True)

# If street name & number not useful:
df.drop(columns=['STREET_NO','STREET_NAME','STREET_DIRECTION'], inplace=True)

# %%
df.head()
# Out:
#    CRASH_DATE_EST_I          CRASH_DATE  POSTED_SPEED_LIMIT  \
# 0                 1 2024-06-23 14:27:00                  30
# 1                 1 2025-02-22 03:00:00                  30
# 2                 1 2021-10-27 14:16:00                  30
# 3                 1 2023-07-05 17:00:00                  30
# 4                 1 2019-09-11 08:30:00                  30
#
#    TRAFFIC_CONTROL_DEVICE  DEVICE_CONDITION  WEATHER_CONDITION  \
# 0                      16                 1                  2
# 1                       4                 3                  2
# 2                       4                 3                  2
# 3                      16                 6                  2
# 4                      15                 1                  2
#
#    LIGHTING_CONDITION  FIRST_CRASH_TYPE  TRAFFICWAY_TYPE  LANE_CNT  ...  \
# 0                   3                17               11       2.0  ...
# 1                   1                 7               10       2.0  ...
# 2                   3                14                8       2.0  ...
# 3                   3                15                2       2.0  ...
# 4                   3                10                2       2.0  ...
#
#    INJURIES_REPORTED_NOT_EVIDENT  INJURIES_NO_INDICATION  INJURIES_UNKNOWN  \
# 0                              0                       2                 0
# 1                              0                       1                 0
# 2                              0                       3                 0
# 3                              0                       2                 0
# 4                              0                       2                 0
#
#    CRASH_HOUR  CRASH_DAY_OF_WEEK  CRASH_MONTH   LATITUDE  LONGITUDE  \
# 0          14                  1            6  41.864897 -87.616781
# 1           3                  7            2  41.782577 -87.614322
# 2          14                  4           10  41.845306 -87.644169
# 3          17                  4            7  41.953968 -87.727479
# 4           8                  4            9  41.930973 -87.779905
#
#    CRASH_YEAR CRASH_DAY
# 0        2024         3
# 1        2025         2
# 2        2021         6
# 3        2023         6
# 4        2019         6
#
# [5 rows x 45 columns]

# %% [markdown]
# # Final Clean Dataset

# %%
df.to_csv(r"D:\#Great Learning\Capstone Project\clean_data\cleaned_crash_data.csv", index=False)
