# %% [markdown]
# We have apply statistical test for checking that the sample we created is belongs to population or not.
#
# The distribution of every variable in the sample should not be statistically different from the distribution in the population.

# %%
# Import Libraries
import pandas as pd
import numpy as np
from scipy.stats import ks_2samp, ttest_ind, levene, chisquare
from statsmodels.stats.proportion import proportions_ztest
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Load Dataset

# %%
population = pd.read_csv(r"D:\#Great Learning\Capstone Project\Datasets\Traffic_Crashes_-_Crashes.csv")
sample = pd.read_csv(r"D:\#Great Learning\Capstone Project\Datasets\crash_data.csv")
results = []

# Track processed columns to avoid duplicates
processed = set()

# %% [markdown]
# # Numerical Distribution Test

# %%
num_cols = population.select_dtypes(include=['int64', 'float64']).columns

for col in num_cols:
    if col in processed:
        continue
    
    # Check if actually binary (encoded as numeric)
    if population[col].nunique() <= 2:
        continue  # Will be handled in binary section
    
    pop = population[col].dropna()
    smp = sample[col].dropna()
    
    # Skip if insufficient data
    if len(pop) < 3 or len(smp) < 3:
        results.append([col, "Numerical", None, None, None, 
                       "Insufficient data", "Cannot assess"])
        processed.add(col)
        continue
    
    # Primary test: KS test for distribution equality
    ks_stat, ks_p = ks_2samp(pop, smp)
    
    # Additional diagnostics (optional)
    try:
        t_stat, t_p = ttest_ind(pop, smp, equal_var=False)
        lev_stat, lev_p = levene(pop, smp)
    except:
        t_p, lev_p = None, None
    
    results.append([
        col, "Numerical", ks_p, t_p, lev_p,
        f"KS test (stat={ks_stat:.3f})",
        "Same distribution" if ks_p > 0.05 else "Different distribution"
    ])
    processed.add(col)

# %% [markdown]
# # Categorical Test (Chi-Square)

# %%
cat_cols = population.select_dtypes(include='object').columns

for col in cat_cols:
    if col in processed:
        continue
    
    # Get value counts for both datasets
    pop_counts = population[col].fillna("NA").value_counts()
    smp_counts = sample[col].fillna("NA").value_counts()
    
    # Align categories (use population categories as reference)
    all_categories = pop_counts.index.tolist()
    
    # Expected frequencies from population proportions
    pop_props = pop_counts / len(population)
    expected = pop_props * len(sample)
    
    # Observed frequencies in sample
    observed = [smp_counts.get(cat, 0) for cat in all_categories]
    expected = expected.values
    
    # Chi-square goodness-of-fit test
    if len(all_categories) > 1 and sum(expected > 5) >= len(expected) * 0.8:
        chi_stat, chi_p = chisquare(observed, expected)
        test_desc = f"Chi-square GOF (stat={chi_stat:.3f})"
        conclusion = "Same distribution" if chi_p > 0.05 else "Different distribution"
    else:
        chi_p = None
        test_desc = "Chi-square GOF (warning: low expected frequencies)"
        conclusion = "Cannot reliably assess"
    
    results.append([
        col, "Categorical", chi_p, None, None,
        test_desc, conclusion
    ])
    processed.add(col)

# %% [markdown]
# # Binary Proportion Test

# %%
# Include numeric columns with exactly 2 unique values
for col in population.columns:
    if col in processed:
        continue
    
    pop_unique = population[col].dropna().nunique()
    smp_unique = sample[col].dropna().nunique()
    
    if pop_unique == 2 and smp_unique <= 2:
        # Get the "positive" class (typically 1, True, or second category)
        pop_vals = population[col].dropna()
        smp_vals = sample[col].dropna()
        
        # Count successes (use the less common value or 1/True)
        pop_categories = pop_vals.unique()
        if len(pop_categories) < 2:
            processed.add(col)
            continue
            
        # Use consistent category ordering
        positive_class = sorted(pop_categories)[1] if population[col].dtype != 'object' else pop_categories[0]
        
        pop_success = (pop_vals == positive_class).sum()
        smp_success = (smp_vals == positive_class).sum()
        
        count = np.array([smp_success, pop_success])
        nobs = np.array([len(smp_vals), len(pop_vals)])
        
        try:
            z_stat, z_p = proportions_ztest(count, nobs)
            results.append([
                col, "Binary", z_p, None, None,
                f"Two-proportion Z-test (z={z_stat:.3f})",
                "Same distribution" if z_p > 0.05 else "Different distribution"
            ])
        except:
            results.append([
                col, "Binary", None, None, None,
                "Two-proportion Z-test failed",
                "Cannot assess"
            ])
        
        processed.add(col)

# %% [markdown]
# # Final Result

# %%
report = pd.DataFrame(results, columns=[
    "Column", "Type", "Main Test P-value", "T-test p",
    "Levene p", "Test Applied", "Conclusion"
])

# Sort by p-value to highlight most different columns
report_sorted = report.sort_values("Main Test P-value", na_position='last')

report_sorted.to_csv("final_stats_report.csv", index=False)

# Summary statistics
print("="*70)
print("POPULATION vs SAMPLE COMPARISON REPORT")
print("="*70)
print(f"\nTotal columns analyzed: {len(report)}")
print(f"Same distribution (p > 0.05): {(report['Main Test P-value'] > 0.05).sum()}")
print(f"Different distribution (p ≤ 0.05): {(report['Main Test P-value'] <= 0.05).sum()}")
print(f"Cannot assess: {report['Main Test P-value'].isna().sum()}")
print("\n" + "="*70)
print("\nDetailed Results:\n")
print(report_sorted.to_string(index=False))
print("\n" + "="*70)
# Out:
# ======================================================================
# POPULATION vs SAMPLE COMPARISON REPORT
# ======================================================================
#
# Total columns analyzed: 47
# Same distribution (p > 0.05): 42
# Different distribution (p ≤ 0.05): 0
# Cannot assess: 5
#
# ======================================================================
#
# Detailed Results:
#
#                        Column        Type  Main Test P-value  T-test p  Levene p                                       Test Applied             Conclusion
#                   WORK_ZONE_I Categorical           0.142024       NaN       NaN                        Chi-square GOF (stat=3.904)      Same distribution
#              STREET_DIRECTION Categorical           0.169021       NaN       NaN                        Chi-square GOF (stat=6.434)      Same distribution
#          ROADWAY_SURFACE_COND Categorical           0.180815       NaN       NaN                        Chi-square GOF (stat=8.874)      Same distribution
#            BEAT_OF_OCCURRENCE   Numerical           0.391038  0.211358  0.221534                               KS test (stat=0.002)      Same distribution
#               TRAFFICWAY_TYPE Categorical           0.395764       NaN       NaN                       Chi-square GOF (stat=19.980)      Same distribution
#                WORK_ZONE_TYPE Categorical           0.407975       NaN       NaN                        Chi-square GOF (stat=3.985)      Same distribution
#        INTERSECTION_RELATED_I Categorical           0.496110       NaN       NaN                        Chi-square GOF (stat=1.402)      Same distribution
#              FIRST_CRASH_TYPE Categorical           0.511426       NaN       NaN                       Chi-square GOF (stat=16.176)      Same distribution
#                 HIT_AND_RUN_I Categorical           0.526718       NaN       NaN                        Chi-square GOF (stat=1.282)      Same distribution
#            NOT_RIGHT_OF_WAY_I Categorical           0.561568       NaN       NaN                        Chi-square GOF (stat=1.154)      Same distribution
#                     DOORING_I Categorical           0.572611       NaN       NaN                        Chi-square GOF (stat=1.115)      Same distribution
#                PHOTOS_TAKEN_I Categorical           0.590104       NaN       NaN                        Chi-square GOF (stat=1.055)      Same distribution
#                     LONGITUDE   Numerical           0.672355  0.116968  0.159587                               KS test (stat=0.002)      Same distribution
#                        DAMAGE Categorical           0.675063       NaN       NaN                        Chi-square GOF (stat=0.786)      Same distribution
#                   ROAD_DEFECT Categorical           0.682374       NaN       NaN                        Chi-square GOF (stat=3.958)      Same distribution
#             WORKERS_PRESENT_I Categorical           0.710452       NaN       NaN                        Chi-square GOF (stat=0.684)      Same distribution
#        TRAFFIC_CONTROL_DEVICE Categorical           0.727769       NaN       NaN                       Chi-square GOF (stat=14.020)      Same distribution
#              DEVICE_CONDITION Categorical           0.744436       NaN       NaN                        Chi-square GOF (stat=4.302)      Same distribution
#                      LATITUDE   Numerical           0.793668  0.193034  0.157190                               KS test (stat=0.001)      Same distribution
#            STATEMENTS_TAKEN_I Categorical           0.834086       NaN       NaN                        Chi-square GOF (stat=0.363)      Same distribution
#                    CRASH_TYPE Categorical           0.854315       NaN       NaN                        Chi-square GOF (stat=0.034)      Same distribution
#                   CRASH_MONTH   Numerical           0.905652  0.377882  0.601691                               KS test (stat=0.001)      Same distribution
#              CRASH_DATE_EST_I Categorical           0.913508       NaN       NaN                        Chi-square GOF (stat=0.181)      Same distribution
#                    CRASH_HOUR   Numerical           0.917191  0.348477  0.786772                               KS test (stat=0.001)      Same distribution
#                     STREET_NO   Numerical           0.929628  0.790039  0.606155                               KS test (stat=0.001)      Same distribution
#                   REPORT_TYPE Categorical           0.938714       NaN       NaN                        Chi-square GOF (stat=0.407)      Same distribution
#             CRASH_DAY_OF_WEEK   Numerical           0.947779  0.763145  0.632232                               KS test (stat=0.001)      Same distribution
#        SEC_CONTRIBUTORY_CAUSE Categorical           0.968019       NaN       NaN                       Chi-square GOF (stat=24.338)      Same distribution
#                     ALIGNMENT Categorical           0.974663       NaN       NaN                        Chi-square GOF (stat=0.836)      Same distribution
#            POSTED_SPEED_LIMIT   Numerical           0.988823  0.649261  0.595589                               KS test (stat=0.001)      Same distribution
#       PRIM_CONTRIBUTORY_CAUSE Categorical           0.993309       NaN       NaN                       Chi-square GOF (stat=20.574)      Same distribution
#                      LANE_CNT   Numerical           0.994692  0.493818  0.647405                               KS test (stat=0.002)      Same distribution
#        INJURIES_NO_INDICATION   Numerical           0.996596  0.482495  0.365091                               KS test (stat=0.001)      Same distribution
#            MOST_SEVERE_INJURY Categorical           0.997498       NaN       NaN                        Chi-square GOF (stat=0.308)      Same distribution
#                     NUM_UNITS   Numerical           0.999790  0.241427  0.707035                               KS test (stat=0.001)      Same distribution
#            LIGHTING_CONDITION Categorical           0.999993       NaN       NaN                        Chi-square GOF (stat=0.028)      Same distribution
#             WEATHER_CONDITION Categorical           1.000000       NaN       NaN                        Chi-square GOF (stat=0.366)      Same distribution
# INJURIES_REPORTED_NOT_EVIDENT   Numerical           1.000000  0.627179  0.629566                               KS test (stat=0.000)      Same distribution
#   INJURIES_NON_INCAPACITATING   Numerical           1.000000  0.497473  0.500452                               KS test (stat=0.000)      Same distribution
#       INJURIES_INCAPACITATING   Numerical           1.000000  0.937521  0.937559                               KS test (stat=0.000)      Same distribution
#                INJURIES_FATAL   Numerical           1.000000  0.668099  0.672403                               KS test (stat=0.000)      Same distribution
#                INJURIES_TOTAL   Numerical           1.000000  0.405027  0.408438                               KS test (stat=0.000)      Same distribution
#               CRASH_RECORD_ID Categorical                NaN       NaN       NaN Chi-square GOF (warning: low expected frequencies) Cannot reliably assess
#                    CRASH_DATE Categorical                NaN       NaN       NaN Chi-square GOF (warning: low expected frequencies) Cannot reliably assess
#          DATE_POLICE_NOTIFIED Categorical                NaN       NaN       NaN Chi-square GOF (warning: low expected frequencies) Cannot reliably assess
#                   STREET_NAME Categorical                NaN       NaN       NaN Chi-square GOF (warning: low expected frequencies) Cannot reliably assess
#                      LOCATION Categorical                NaN       NaN       NaN Chi-square GOF (warning: low expected frequencies) Cannot reliably assess
#
# ======================================================================
